# %%
import pandas as pd

# %%
df=pd.read_excel("/content/FAQData.xlsx",header=None)
df
# Out:
#                                                     0  \
# 0   What documents are required to be submitted fo...
# 1                       Meaning of Program and Course
# 2   Is the Online Program offered by JAIN (Deemed-...
# 3   Is the Degree acquired through online mode equ...
# 4   Is this an Open and Distance Learning (ODL) Pr...
# 5                          Who will award the Degree?
# 6                  What is the medium of instruction?
# 7   When should Elective (Specialization) be indic...
# 8   Can elective/program be changed after Program ...
# 9                What is the duration of the Program?
# 10  What is the maximum period for Program complet...
# 11  Does the Program follow Semester or Annual Sch...
# 12            How many credits does the Program have?
# 13              How many learning hours are involved?
# 14            How many courses does the Program have?
# 15       In which semester elective courses commence?
# ...

# %%
for count,data in enumerate(zip(df[0],df[1])):
  print(count,"::"," Questions :",data[0]," Answers ", data[1])
# Out:
# 0 ::  Questions : What documents are required to be submitted for admission?  Answers  Colour scan of the below mentioned original document is required to be uploaded on the admission portal at the time of seeking admission –
# Grade sheet of Class 10
# Grade sheet of Class 12
# Grade sheet of all the Semesters of Bachelor’s Degree / Consolidated mark sheet (Only for PG Programs)
# Degree Certificate / Provisional Degree Certificate (Only for PG Programs)
# Aadhar Card for Indian Nationals and Passport for Foreign Nationals
# 1 ::  Questions : Meaning of Program and Course  Answers  B.Com is a Program; Introduction to Accounting is a Course (Subject)
# 2 ::  Questions : Is the Online Program offered by JAIN (Deemed-to-be University) recognized?  Answers  Yes, the University is Entitled by University Grants Commission (UGC) to offer Online Degree Programs. Additionally, MBA and MCA Programs are approved by All India Council for Technical Education (AICTE).
# ...
